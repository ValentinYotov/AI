# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.ion()
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported-car-sales.csv", index=False)
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
##няма (), защото не е функция а трибут 
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_prices = pd.Series([3000,1500,111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales.Colour.sum()
# Out:
# 'WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite'

# %%
car_sales.Doors.sum()
# Out:
# 40

# %%
car_sales.Doors.sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
#VIEWING AND SELECTING DATA

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc и .iloc

# %%
animals = pd.Series(['Cat',"dog",'bird','panda','snake'],index = [0,3,9,8,3])

# %%
animals
# Out:
# 0      Cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[8]
# Out:
# 'panda'

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      Cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[1]
# Out:
# 'dog'

# %%
animals.iloc[:3]
# Out:
# 0     Cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals.iloc[3-1:]
# Out:
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'],car_sales['Price'])
# Out:
# Price   $22,000.00  $3,500.00  $4,000.00  $4,500.00  $5,000.00  $6,250.00  \
# Make
# BMW              1          0          0          0          0          0
# Honda            0          0          0          0          1          0
# Nissan           0          1          0          0          0          0
# Toyota           0          0          1          1          0          1
#
# Price   $7,000.00  $7,500.00  $9,700.00
# Make
# BMW             0          0          0
# Honda           1          1          0
# Nissan          0          0          1
# Toyota          1          0          0

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales['Make']=car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_missing = pd.read_csv("car-sales-missing-data.csv")
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
seats_column = pd.Series([5,5,5,5,5])

car_sales['Seats'] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales['Seats'] = car_sales['Seats'].fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    5.0
# 6   honda   Blue          45698      4   $7,500.00    5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0
# 8  toyota  White          60000      4   $6,250.00    5.0
# 9  nissan  White          31600      4   $9,700.00    5.0

# %%
fuel = [7.5,9.2,5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.6]

# %%
car_sales['Fuel per 100'] = fuel

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100
# 0  toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0           9.6
# 4  nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 8  toyota  White          60000      4   $6,250.00    5.0           3.0
# 9  nissan  White          31600      4   $9,700.00    5.0           4.6

# %%
car_sales['Total fuel used'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0           9.6
# 4  nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 8  toyota  White          60000      4   $6,250.00    5.0           3.0
# 9  nissan  White          31600      4   $9,700.00    5.0           4.6
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# ...

# %%
car_sales['Wheels'] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0           9.6
# 4  nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 8  toyota  White          60000      4   $6,250.00    5.0           3.0
# 9  nissan  White          31600      4   $9,700.00    5.0           4.6
#
#    Total fuel used  Wheels
# 0        11253.225       4
# 1         8086.708       4
# 2         1627.450       4
# 3         1073.184       4
# 4        18539.265       4
# ...

# %%
car_sales = car_sales.drop('Total fuel used', axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0           9.6
# 4  nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 8  toyota  White          60000      4   $6,250.00    5.0           3.0
# 9  nissan  White          31600      4   $9,700.00    5.0           4.6
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %%
car_sales['Random'] = car_sales['Make']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0           9.6
# 4  nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 8  toyota  White          60000      4   $6,250.00    5.0           3.0
# 9  nissan  White          31600      4   $9,700.00    5.0           4.6
#
#    Wheels  Random
# 0       4  toyota
# 1       4   honda
# 2       4  toyota
# 3       4     bmw
# 4       4  nissan
# 5       4  toyota
# 6       4   honda
# 7       4   honda
# ...

# %%
car_sales_shu = car_sales.sample(frac = 1)

# %%
car_sales_shu
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 6   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 8  toyota  White          60000      4   $6,250.00    5.0           3.0
# 5  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 1   honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 4  nissan  White         213095      4   $3,500.00    5.0           8.7
# 9  nissan  White          31600      4   $9,700.00    5.0           4.6
# 0  toyota  White         150043      4   $4,000.00    5.0           7.5
# 3     bmw  Black          11179      5  $22,000.00    5.0           9.6
#
#    Wheels  Random
# 6       4   honda
# 8       4  toyota
# 5       4  toyota
# 1       4   honda
# 2       4  toyota
# 7       4   honda
# 4       4  nissan
# 9       4  nissan
# ...

# %%
car_sales_shu = car_sales_shu.reset_index(drop = True)

# %%
car_sales_shu
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 1  toyota  White          60000      4   $6,250.00    5.0           3.0
# 2  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 3   honda    Red          87899      4   $5,000.00    5.0           9.2
# 4  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 5   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 6  nissan  White         213095      4   $3,500.00    5.0           8.7
# 7  nissan  White          31600      4   $9,700.00    5.0           4.6
# 8  toyota  White         150043      4   $4,000.00    5.0           7.5
# 9     bmw  Black          11179      5  $22,000.00    5.0           9.6
#
#    Wheels  Random
# 0       4   honda
# 1       4  toyota
# 2       4  toyota
# 3       4   honda
# 4       4  toyota
# 5       4   honda
# 6       4  nissan
# 7       4  nissan
# ...

# %%
car_sales_shu
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 1  toyota  White          60000      4   $6,250.00    5.0           3.0
# 2  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 3   honda    Red          87899      4   $5,000.00    5.0           9.2
# 4  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 5   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 6  nissan  White         213095      4   $3,500.00    5.0           8.7
# 7  nissan  White          31600      4   $9,700.00    5.0           4.6
# 8  toyota  White         150043      4   $4,000.00    5.0           7.5
# 9     bmw  Black          11179      5  $22,000.00    5.0           9.6
#
#    Wheels  Random
# 0       4   honda
# 1       4  toyota
# 2       4  toyota
# 3       4   honda
# 4       4  toyota
# 5       4   honda
# 6       4  nissan
# 7       4  nissan
# ...

# %%
car_sales_shu
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 1  toyota  White          60000      4   $6,250.00    5.0           3.0
# 2  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 3   honda    Red          87899      4   $5,000.00    5.0           9.2
# 4  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 5   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 6  nissan  White         213095      4   $3,500.00    5.0           8.7
# 7  nissan  White          31600      4   $9,700.00    5.0           4.6
# 8  toyota  White         150043      4   $4,000.00    5.0           7.5
# 9     bmw  Black          11179      5  $22,000.00    5.0           9.6
#
#    Wheels  Random
# 0       4   honda
# 1       4  toyota
# 2       4  toyota
# 3       4   honda
# 4       4  toyota
# 5       4   honda
# 6       4  nissan
# 7       4  nissan
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0           9.6
# 4  nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0           7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0           8.7
# 8  toyota  White          60000      4   $6,250.00    5.0           3.0
# 9  nissan  White          31600      4   $9,700.00    5.0           4.6
#
#    Wheels  Random
# 0       4  toyota
# 1       4   honda
# 2       4  toyota
# 3       4     bmw
# 4       4  nissan
# 5       4  toyota
# 6       4   honda
# 7       4   honda
# ...

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0           7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0           9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0           5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0           9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0           8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0           4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0           7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0           8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0           3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0           4.6
#
#    Wheels  Random
# 0       4  toyota
# 1       4   honda
# 2       4  toyota
# 3       4     bmw
# 4       4  nissan
# 5       4  toyota
# 6       4   honda
# 7       4   honda
# ...

# %%
car_sales.Price.dtype
# Out:
# dtype('O')

# %%
car_sales.Doors.plot()
# Out:
# <Axes: >

# %%
plt.show()

# %%
car_sales['Fuel per 100'].plot()
# Out:
# <Axes: >

# %%
plt.show()

# %%
car_sales['Fuel per 100'].hist()
# Out:
# <Axes: >

# %%
plt.show()

# %%
car_sales['New'] = car_sales["Doors"].apply(lambda x: x+1)

# %%
car_sales = car_sales.drop('New',axis = 1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0           7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0           9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0           5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0           9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0           8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0           4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0           7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0           8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0           3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0           4.6
#
#    Wheels  Random
# 0       4  toyota
# 1       4   honda
# 2       4  toyota
# 3       4     bmw
# 4       4  nissan
# 5       4  toyota
# 6       4   honda
# 7       4   honda
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0           7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0           9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0           5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0           9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0           8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0           4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0           7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0           8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0           3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0           4.6
#
#    Wheels  Random
# 0       4  toyota
# 1       4   honda
# 2       4  toyota
# 3       4     bmw
# 4       4  nissan
# 5       4  toyota
# 6       4   honda
# 7       4   honda
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0           7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0           9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0           5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0           9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0           8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0           4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0           7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0           8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0           3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0           4.6
#
#    Wheels  Random
# 0       4  toyota
# 1       4   honda
# 2       4  toyota
# 3       4     bmw
# 4       4  nissan
# 5       4  toyota
# 6       4   honda
# 7       4   honda
# ...

# %%
car_sales['Random'] = car_sales['Make'] + car_sales['Colour']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0           7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0           9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0           5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0           9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0           8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0           4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0           7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0           8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0           3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0           4.6
#
#    Wheels       Random
# 0       4  toyotaWhite
# 1       4     hondaRed
# 2       4   toyotaBlue
# 3       4     bmwBlack
# 4       4  nissanWhite
# 5       4  toyotaGreen
# ...
