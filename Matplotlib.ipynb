# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a1 = plt.plot()

# %%
plt.plot([1,2,3,4,5]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)

# %%
fig = plt.figure()
ax = fig.add_subplot()

# %%
fig,ax = plt.subplots()
ax.plot(x,y);
